# %% [markdown]
# TÍTULO PRÁCTICA: Desarrollo de un algoritmo en paralelo para generar una bolsa de
# palabras de la red social Twitte

# %% [markdown]
# 1. Extraer información de Twitter

# %%
import tweepy
import time

import pandas as pd
consumer_key ="h5Ff6DSty1xtqgb5ekFqPJNdR"
consumer_secret = "VrmEZSxJb17amL9GLvsbRX3omgbcQWQKzo3Fr065IYTZaLpX5B"
access_token= "3092881449-aBD4JirmNCN08pIFN3kk5yGPIRusJN0heDH2f1i"
access_token_secret = "NrNzODcFhowdzg2dL2YSmSZ5euoBCj849syPOoY0cOYMQ"

auth = tweepy.OAuth1UserHandler(
   consumer_key, consumer_secret, access_token, access_token_secret
)

api = tweepy.API(auth)
Usuario = '@RichardCarapazM'

id = None
count = 0
while count <= 6000:
    tweets = api.search_tweets(q= Usuario, lang='es', tweet_mode='extended', max_id=id)
    time.sleep(1)
    for tweet in tweets:
        if tweet.full_text.startswith('RT'):
            count += 1
            continue
        f = open('dato.csv', 'a', encoding='utf-8')
        f.write(tweet.full_text + '\n')
        f.close

        count += 1
        id = tweet.id

print("Datos Extraidos Correctamente")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_9440/1191305021.py in <module>
#      18 count = 0
#      19 while count <= 6000:
# ---> 20     tweets = api.search_tweets(q= Usuario, lang='es', tweet_mode='extended', max_id=id)
#      21     time.sleep(1)
#      22     for tweet in tweets:
#
# ~/anaconda3/lib/python3.9/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~/anaconda3/lib/python3.9/site-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1301         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1302         """
# -> 1303         return self.request(
#    1304             'GET', 'search/tweets', endpoint_parameters=(
#    1305                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# ~/anaconda3/lib/python3.9/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     261                 raise NotFound(resp)
#     262             if resp.status_code == 429:
# --> 263                 raise TooManyRequests(resp)
#     264             if resp.status_code >= 500:
#     265                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
import pandas as pd
data = pd.read_csv('dato.csv', sep='\n');
data
# Out:
#     @esthercuestasan @RichardCarapazM @literatango @radiolacalle @FaustoJarrinT @jpjaramillo25 @giroditalia @virgiliohernand @RC5Oficial @RC5Europa @Italia_RC @Revolucionspana @CRCMovimientoIb Alegría que nos llena el alma a los Migrantes 🇪🇨
# 0    🔥🚂🇪🇨 La 12da etapa del @giroditalia fue para l...
# 1    @pedrollerenam @giroditalia @mario_sabato @Rod...
# 2    Que orgullo @RichardCarapazM desde el #GiroDIt...
# 3    ---&gt; La CG sigue en vigencia a @juanpelopez...
# 4    @INEOSGrenadiers @RichardCarapazM @jcastroviej...
# ..                                                 ...
# 292  @giroditalia @RichardCarapazM @INEOSGrenadiers...
# 293  @giroditalia @RichardCarapazM @INEOSGrenadiers...
# 294  @giroditalia @RichardCarapazM @INEOSGrenadiers...
# 295  @giroditalia @RichardCarapazM @INEOSGrenadiers...
# 296  @giroditalia @RichardCarapazM @INEOSGrenadiers...
#
# [297 rows x 1 columns]

# %% [markdown]
# Limpieza de datos

# %%
#Escluir palabras que siempre se repiten
exclude_words = ['😡','🤣','🐖🐖','👉https://t.co/69ra2jnd6v','😢','🤷🏻\u200d♀️','🤦🏽\u200d♂️🤦🏽\u200d♂️,','diablo.👹','✈️','🤫','🤦🏽','🙊','⤵️','👉','🦖','🧐','👉','🚨denuncia','😬','el', 'la', 'los', 'las', 'un', 'una', 'unos', 'unas', 'al', 'del', 'lo', 'le', 'y', 'e', 'o', 'u', 'de', 'a', 'en', 'que', 'es', 'por', 'para', 'con', 'se', 'su', 'les', 'me', 'q', 'te', 'pero', 'mi', 'ya', 'cuando', 'como', 'estoy', 'voy', 'porque', 'he', 'son', 'solo', 'tengo', 'muy']

# %%
#funcion guardar 
def guardarDatos(nc, name):
    
    f = open(name+'.txt', "a",  encoding="utf-8")

    for i in nc:
        f.write(str(i))
    f.close() 
print ('ok')
# Out:
# ok

# %%
#bibleoteca completa 
#pilas
BibleotecaCompleta = []

for i in range (len(data)):
        BibleotecaCompleta.append(data [0:i])
        
print(len(BibleotecaCompleta))

guardarDatos(BibleotecaCompleta, 'BibleotecaCompleta')
# Out:
# 297

# %% [markdown]
#  Cree una bolsa de palabras de todos los tweets, es decir un
# diccionario que tenga ‘palabra’: # de veces que se repite.

# %%
def datosMasNombrados():
    import time
    time.sleep(5)
    most_used_words = sorted(top_words, key=top_words.get, reverse=True)
    print('*'*40) # esto es para separar visualmente la información

    print("Los mas nombrados") # esto es para separar visualmente la información

    print('*'*40) # esto es para separar visualmente la información
    count_u = 0
    for word in most_used_words:
        if count_u < 20 and word.startswith('@'):
            print(top_words[word], word)
            count_u += 1
    print('*'*40) # esto es para separar visualmente la información
    print("con mas #") # esto es para separar visualmente la información
    print('*'*40) # esto es para separar visualmente la información

    count_u = 0
    for word in most_used_words:
        if count_u < 20 and word.startswith('#'):
            print(top_words[word], word)
            count_u += 1

    print('*'*40) # esto es para separar visualmente la información

# %% [markdown]
#  Cree un listado de hashtags más utilizados, es decir un diccionario
# que tenga ‘hashtag’: # de veces que se twittea.

# %%
from time import time
start_time = time()
top_words = {}
tweets_topic = open('BibleotecaCompleta.txt', encoding='utf-8')
for line in tweets_topic:
    words = line.strip().lower().split()
    for word in words:
        if word not in exclude_words:
            top_words[word] = top_words.get(word, 0) + 1

datosMasNombrados()
elapsed_time = time() - start_time
top_words

print("Tiempo Secuencial: %f segundos" % elapsed_time)
# Out:
# ****************************************
# Los mas nombrados
# ****************************************
# 7203 @richardcarapazm
# 5592 @giroditalia
# 2598 @ineosgrenadiers...
# 1824 @ineosgrenadiers
# 1428 @jcastroviej...
# 1026 @pedrollerenam
# 1026 @mario_sabato
# 1026 @rod...
# 891 @literatango
# 891 @radiolacalle
# 891 @faustojarrint
# 891 @jpjaramillo25
# 891 @virgiliohernand
# 891 @rc5oficial
# 891 @rc5europa
# 891 @italia_rc
# 891 @revolucionspana
# 891 @crcmovimientoib
# 888 @esthercuestasan
# 879 @juanpelopez...
# ****************************************
# con mas #
# ****************************************
# 882 #girodit...
# 282 #giro
# 246 #girodeitalia2022
# 162 #ppdeportes
# 147 #giroditalia
# 144 #giro🇮🇹🚴‍♂️
# 132 #eldeportequequeremos
# 123 #deportes:
# 123 #girodeit...
# 111 #laradioquesiempreestá
# 102 #carapaz
# 102 #ecuador
# 102 #giro2022
# 84 #strongertogether
# 72 #génova
# 63 #latriviadeoro🥇
# 30 #elgiroendirectv
# 30 #richineta
# 30 #yoconelmovistarteam
# 30 #vamosrichie
# ****************************************
# Tiempo Secuencial: 5.173182 segundos

# %%
top_words
# Out:
# {'empty': 1,
#  'dataframe': 3,
#  'columns:': 3,
#  '[@esthercuestasan': 3,
#  '@richardcarapazm': 7203,
#  '@literatango': 891,
#  '@radiolacalle': 891,
#  '@faustojarrint': 891,
#  '@jpjaramillo25': 891,
#  '@giroditalia': 5592,
#  '@virgiliohernand': 891,
#  '@rc5oficial': 891,
#  '@rc5europa': 891,
#  '@italia_rc': 891,
#  '@revolucionspana': 891,
#  '@crcmovimientoib': 891,
#  'alegría': 891,
#  'nos': 906,
#  'llena': 891,
#  'alma': 891,
#  'migrantes': 891,
#  '🇪🇨]': 3,
#  'index:': 3,
#  '[]': 3,
#  '@esthercuestasan': 888,
#  '🇪🇨': 1017,
#  '0': 888,
#  '🔥🚂🇪🇨': 888,
#  '12da': 888,
#  'etapa': 1788,
#  'fue': 888,
#  'l...': 888,
#  '1': 1593,
#  '@pedrollerenam': 1026,
#  '@mario_sabato': 1026,
#  '@rod...': 1026,
#  '2': 897,
#  'orgullo': 882,
#  'desde': 912,
#  '#girodit...': 882,
#  '3': 879,
#  '---&gt;': 879,
#  'cg': 879,
#  'sigue': 879,
#  'vigencia': 879,
#  '@juanpelopez...': 879,
#  '4': 876,
#  '@ineosgrenadiers': 1824,
#  '@jcastroviej...': 1428,
#  '5': 165,
#  '6': 162,
#  '#ppdeportes': 162,
#  '|': 408,
#  'tras': 177,
#  '12,': 267,
#  'ecuatoriano...': 162,
#  '7': 159,
#  '🚴🏽\u200d♂️el': 159,
#  'ecuatoriano': 159,
#  'está': 189,
#  '12': 843,
#  'segundos': 159,
#  'líd...': 159,
#  '8': 156,
#  'supuesto': 156,
#  'no': 192,
#  'puede': 237,
#  'faltar': 156,
#  '@yosoybarcelona': 156,
#  'e...': 156,
#  '9': 153,
#  '@ineosgrenadiers...': 2598,
#  '10': 150,
#  '11': 147,
#  'estamos': 174,
#  'disfrutando': 147,
#  '#giroditalia': 147,
#  '🇮🇹': 261,
#  'gén...': 147,
#  '#giro🇮🇹🚴\u200d♂️': 144,
#  '13': 141,
#  'clasificación': 246,
#  'general': 237,
#  'luego': 207,
#  'del...': 171,
#  '14': 138,
#  'vamos': 360,
#  ',': 336,
#  'vitamina': 273,
#  'alm...': 273,
#  '15': 135,
#  '16': 132,
#  '#eldeportequequeremos': 132,
#  '🚵\u200d♀️': 132,
#  'stefano': 342,
#  'oldani': 342,
#  'se...': 147,
#  '17': 129,
#  '@juegosolimpicos': 129,
#  '@ecuadorolim...': 129,
#  '18': 126,
#  '19': 123,
#  '#deportes:': 123,
#  'culminada': 228,
#  '#girodeit...': 123,
#  '20': 120,
#  '21': 117,
#  '22': 114,
#  '#giro': 282,
#  'ganó': 210,
#  '...': 1179,
#  '23': 111,
#  '#laradioquesiempreestá': 111,
#  'https://t.co/onrwq8g20h': 111,
#  '24': 108,
#  'nuestra': 108,
#  'gente': 108,
#  'espectante': 108,
#  'orgullosa': 108,
#  '@richa...': 108,
#  '25': 105,
#  'gen...': 105,
#  '26': 102,
#  '#carapaz': 102,
#  '#ecuador': 102,
#  '#giro2022': 102,
#  '27': 99,
#  '#girodeitalia2022': 246,
#  'https://...': 99,
#  '28': 96,
#  '@girodital...': 96,
#  '29': 93,
#  '¡la': 93,
#  'histórica': 93,
#  'medalla': 93,
#  '@richardcarapazm!': 93,
#  '🇪🇨✨': 93,
#  '30': 90,
#  'hoy': 90,
#  'recordamos': 90,
#  'carrera': 90,
#  'ciclismo': 90,
#  'ruta': 90,
#  '31': 87,
#  'richard': 177,
#  'llevó': 87,
#  'país': 87,
#  'más': 102,
#  'alto': 87,
#  'podi...': 87,
#  '32': 84,
#  '#strongertogether': 84,
#  '33': 81,
#  '@ecuadorolimpico': 81,
#  'https://t.co/zjag0dt2rr': 81,
#  '34': 78,
#  'llega': 153,
#  'todos': 153,
#  'sus': 153,
#  'gregarios': 153,
#  'c...': 228,
#  '35': 75,
#  '36': 72,
#  'pasa': 72,
#  'ahora': 72,
#  '#génova': 72,
#  '37': 69,
#  '@gettysport': 114,
#  '38': 66,
#  '@richardcar...': 66,
#  '39': 63,
#  'tranquila': 63,
#  'cuidá...': 63,
#  '40': 60,
#  '41': 57,
#  'peor': 57,
#  'accidente': 57,
#  '@eganbernal': 57,
#  'lo...': 57,
#  '42': 54,
#  'crónica': 54,
#  'leña': 54,
#  'dieron': 54,
#  'b...': 54,
#  '43': 51,
#  'https://t.co/ya5oohfbio': 51,
#  'https://t.co/saeknzc1ap': 51,
#  '44': 48,
#  '¡vamos!': 93,
#  'https://t.co/pn95u...': 93,
#  '45': 45,
#  '46': 42,
#  '47': 39,
#  'ecuador': 69,
#  'admira': 39,
#  'apoya!': 39,
#  'https://t.co/jvtwbj...': 39,
#  '48': 36,
#  '😳lección.': 36,
#  'mezclar': 36,
#  'política': 36,
#  'dep...': 36,
#  '49': 33,
#  'adelante': 33,
#  'campeón!💪🏽': 33,
#  'https://t.co/zzviccqk4d': 33,
#  '50': 30,
#  'todo': 90,
#  'pendiente': 30,
#  'vam...': 30,
#  '51': 27,
#  'rich...': 27,
#  '52': 24,
#  'nuestro': 54,
#  'campeón': 45,
#  'oro.': 24,
#  '53': 21,
#  'hacer': 21,
#  'fuerza': 36,
#  'positivas': 21,
#  '💪✌️el': 21,
#  'richi': 21,
#  '54': 18,
#  'acabo': 63,
#  'participar': 63,
#  '#latriviadeoro🥇': 63,
#  '@ban...': 63,
#  '55': 15,
#  '¿lo': 60,
#  'sabes': 75,
#  '@richardcarapazm?': 60,
#  'demuéstral...': 60,
#  '56': 15,
#  '57': 15,
#  '58': 15,
#  'carajo!': 15,
#  'https://t.co/p0...': 15,
#  '59': 15,
#  '#elgiroendirectv': 30,
#  '@directvecuador': 60,
#  'saludos': 30,
#  'desde...': 30,
#  '..': 708,
#  '60': 15,
#  'si': 45,
#  'quemar': 30,
#  'leños': 30,
#  '💪🏽🚂': 30,
#  '[61': 3,
#  'rows': 708,
#  'x': 708,
#  'columns]': 706,
#  '61': 15,
#  '[62': 3,
#  '62': 15,
#  '[63': 3,
#  '63': 15,
#  'genio!!!': 15,
#  '[64': 3,
#  '64': 15,
#  '[65': 3,
#  '65': 15,
#  '[66': 3,
#  '66': 15,
#  '#richineta': 30,
#  '[67': 3,
#  '67': 15,
#  '[68': 3,
#  '68': 15,
#  '[69': 3,
#  '69': 15,
#  '[70': 3,
#  '70': 15,
#  '[71': 3,
#  '71': 15,
#  '[72': 3,
#  '72': 15,
#  'hasta': 15,
#  'final': 15,
#  '!!': 15,
#  'http...': 15,
#  '[73': 3,
#  '73': 15,
#  '@damiankoralec': 30,
#  '[74': 3,
#  '74': 15,
#  '[75': 3,
#  '75': 15,
#  '🥳🇪🇨': 15,
#  'subida': 15,
#  '@rodrisabato': 15,
#  '[76': 3,
#  '76': 15,
#  '@lorenpalvarez': 15,
#  '@richardcarapa...': 15,
#  '[77': 3,
#  '77': 15,
#  '🇪🇨🥳': 30,
#  'excelente': 30,
#  '@na...': 30,
#  '[78': 3,
#  '78': 15,
#  '[79': 3,
#  '79': 15,
#  '@papoz68': 105,
#  '¿el...': 15,
#  '[80': 3,
#  '80': 15,
#  'domingo': 30,
#  'veremos': 30,
#  'rosa': 45,
#  '@richardc...': 30,
#  '[81': 3,
#  '81': 15,
#  '[82': 3,
#  '82': 15,
#  'acompañamos': 15,
#  'en...': 15,
#  '[83': 3,
#  '83': 15,
#  '@giroditalia...': 30,
#  '[84': 3,
#  '84': 15,
#  '[85': 3,
#  '85': 15,
#  '@directvsports': 30,
#  '@d...': 30,
#  '[86': 3,
#  '86': 15,
#  'vinces': 30,
#  'provincia': 30,
#  'ríos': 30,
#  '#elgiroendi...': 15,
#  '[87': 3,
#  '87': 15,
#  '[88': 3,
#  '88': 15,
#  '[89': 3,
#  '89': 15,
#  '[90': 3,
#  '90': 15,
#  'que...': 45,
#  '[91': 3,
#  '91': 15,
#  '[92': 3,
#  '92': 15,
#  'hola': 15,
#  'vemos': 15,
#  'pronto!': 15,
#  '[93': 3,
#  '93': 15,
#  'otro': 15,
#  'https://t.co/9hxfx1rddi': 15,
#  '[94': 3,
#  '94': 15,
#  'carapaz': 45,
#  'saluda': 30,
#  'afición': 30,
#  'ecuatorian...': 30,
#  '[95': 3,
#  '95': 15,
#  'https://t.co...': 45,
#  '[96': 3,
#  '96': 15,
#  '[97': 3,
#  '97': 15,
#  '[98': 3,
#  '98': 15,
#  '[99': 3,
#  '99': 15,
#  'esculturas': 15,
#  'gran': 15,
#  'hom...': 15,
#  '[100': 3,
#  '100': 15,
#  '[101': 3,
#  '101': 15,
#  '@movistar_es': 30,
#  '@movistar_team': 30,
#  'escalador': 30,
#  '🚵\u200d♂️✌🏼': 30,
#  '[102': 3,
#  '102': 15,
#  '#yoconelmovistarteam': 30,
#  '🇪🇨🚂🚵\u200d♂️': 30,
#  '[103': 3,
#  '103': 15,
#  '[104': 3,
#  '104': 15,
#  '[105': 3,
#  '105': 15,
#  'murales': 15,
#  'olímpico': 15,
#  'son...': 15,
#  '[106': 3,
#  '106': 15,
#  'https://t.co/koqgfr266w': 15,
#  '[107': 3,
#  '107': 15,
#  '[108': 3,
#  '108': 15,
#  '1️⃣2️⃣': 15,
#  '[109': 3,
#  '109': 15,
#  '2do': 15,
#  'puesto': 15,
#  'gener...': 15,
#  '[110': 3,
#  '110': 15,
#  'clave': 15,
#  'sacar': 15,
#  'diferencias': 15,
#  'etap...': 15,
#  '[111': 3,
#  '111': 15,
#  '#fuerzarichie': 15,
#  'https://t.co/afkye9mvu3': 15,
#  '[112': 3,
#  '112': 15,
#  'bien': 45,
#  '[113': 3,
#  '113': 15,
#  'segundo': 30,
#  '[114': 3,
#  '114': 15,
#  '[115': 3,
#  '115': 15,
#  '[116': 3,
#  '116': 15,
#  '@primicias': 30,
#  '[117': 3,
#  '117': 15,
#  '[118': 3,
#  '118': 15,
#  '[119': 3,
#  '119': 15,
#  'ahh...': 15,
#  '[120': 3,
#  '120': 15,
#  '@ruby_roubaix': 30,
#  '@ineosgrenadier...': 30,
#  '[121': 3,
#  '121': 15,
#  '[122': 3,
#  '122': 15,
#  '¿po...': 15,
#  '[123': 3,
#  '123': 15,
#  '“maglia”': 15,
#  'giro': 30,
#  '🚴🏻': 15,
#  'ser': 15,
#  'tuya': 15,
#  'g...': 15,
#  '[124': 3,
#  '124': 15,
#  'demuestra': 15,
#  'cuánto': 15,
#  '🚂': 15,
#  '[125': 3,
#  '125': 15,
#  'haz': 15,
#  'rt': 15,
#  'like': 15,
#  'recibir': 15,
#  'notificación': 15,
#  '[126': 3,
#  '126': 15,
#  'aciertas,': 15,
#  'entras': 15,
#  'sorteo.': 15,
#  '[127': 3,
#  '127': 15,
#  'habrá': 15,
#  'ganadores.': 15,
#  '👚': 15,
#  'https://t.co/9zzacz5bnn': 15,
#  '[128': 3,
#  '128': 15,
#  'cada': 15,
#  '[129': 3,
#  '129': 15,
#  '[130': 3,
#  '130': 15,
#  '[131': 3,
#  '131': 15,
#  's...': 15,
#  '[132': 3,
#  '132': 15,
#  '#vamosrichie': 30,
#  'mijin!!!': 30,
#  '[133': 3,
#  '133': 15,
#  '[134': 3,
#  '134': 15,
#  'cara...': 30,
#  '[135': 3,
#  '135': 15,
#  '[136': 3,
#  '136': 15,
#  '@funerariaalach': 15,
#  '[137': 3,
#  '137': 15,
#  '@ingomarchamorro': 30,
#  '@richardcarapaz': 30,
#  '@youtube': 30,
#  'deci...': 30,
#  '[138': 3,
#  '138': 15,
#  '[139': 3,
#  '139': 15,
#  '[140': 3,
#  '140': 15,
#  '[141': 3,
#  '141': 15,
#  '[142': 3,
#  '142': 15,
#  '[143': 3,
#  '143': 15,
#  '[144': 3,
#  '144': 15,
#  '[145': 3,
#  '145': 15,
#  '[146': 3,
#  '146': 15,
#  '[147': 3,
#  '147': 15,
#  '[148': 3,
#  '148': 15,
#  '[149': 3,
#  '149': 15,
#  '[150': 3,
#  '150': 15,
#  '[151': 3,
#  '151': 15,
#  '[152': 3,
#  '152': 15,
#  '[153': 3,
#  '153': 15,
#  '[154': 3,
#  '154': 15,
#  '[155': 3,
#  '155': 15,
#  '[156': 3,
#  '156': 15,
#  '[157': 3,
#  '157': 15,
#  '[158': 3,
#  '158': 15,
#  '[159': 3,
#  '159': 15,
#  '[160': 3,
#  '160': 15,
#  '[161': 3,
#  '161': 15,
#  '[162': 3,
#  '162': 15,
#  '[163': 3,
#  '163': 15,
#  '[164': 3,
#  '164': 15,
#  '[165': 3,
#  '165': 15,
#  '[166': 3,
#  '166': 15,
#  '[167': 3,
#  '167': 15,
#  '[168': 3,
#  '168': 15,
#  '[169': 3,
#  '169': 15,
#  '[170': 3,
#  '170': 15,
#  '[171': 3,
#  '171': 15,
#  '[172': 3,
#  '172': 15,
#  '[173': 3,
#  '173': 15,
#  '[174': 3,
#  '174': 15,
#  '[175': 3,
#  '175': 15,
#  '[176': 3,
#  '176': 15,
#  '[177': 3,
#  '177': 15,
#  '[178': 3,
#  '178': 15,
#  '[179': 3,
#  '179': 15,
#  '[180': 3,
#  '180': 15,
#  '[181': 3,
#  '181': 15,
#  '[182': 3,
#  '182': 15,
#  '[183': 3,
#  '183': 15,
#  '[184': 3,
#  '184': 15,
#  '[185': 3,
#  '185': 15,
#  '[186': 3,
#  '186': 15,
#  '[187': 3,
#  '187': 15,
#  '[188': 3,
#  '188': 15,
#  '[189': 3,
#  '189': 15,
#  '[190': 3,
#  '190': 15,
#  '[191': 3,
#  '191': 15,
#  '[192': 3,
#  '192': 15,
#  '[193': 3,
#  '193': 15,
#  '[194': 3,
#  '194': 15,
#  '[195': 3,
#  '195': 15,
#  '[196': 3,
#  '196': 15,
#  '[197': 3,
#  '197': 15,
#  '[198': 3,
#  '198': 15,
#  '[199': 3,
#  '199': 15,
#  '[200': 3,
#  '200': 15,
#  '[201': 3,
#  '201': 15,
#  '[202': 3,
#  '202': 15,
#  '[203': 3,
#  '203': 15,
#  '[204': 3,
#  '204': 15,
#  '[205': 3,
#  '205': 15,
#  '[206': 3,
#  '206': 15,
#  '[207': 3,
#  '207': 15,
#  '[208': 3,
#  '208': 15,
#  '[209': 3,
#  '209': 15,
#  '[210': 3,
#  '210': 15,
#  '[211': 3,
#  '211': 15,
#  '[212': 3,
#  '212': 15,
#  '[213': 3,
#  '213': 15,
#  '[214': 3,
#  '214': 15,
#  '[215': 3,
#  '215': 15,
#  '[216': 3,
#  '216': 15,
#  '[217': 3,
#  '217': 15,
#  '[218': 3,
#  '218': 15,
#  '[219': 3,
#  '219': 15,
#  '[220': 3,
#  '220': 15,
#  '[221': 3,
#  '221': 15,
#  '[222': 3,
#  '222': 15,
#  '[223': 3,
#  '223': 15,
#  '[224': 3,
#  '224': 15,
#  '[225': 3,
#  '225': 15,
#  '[226': 3,
#  '226': 15,
#  '[227': 3,
#  '227': 15,
#  '[228': 3,
#  '228': 15,
#  '[229': 3,
#  '229': 15,
#  '[230': 3,
#  '230': 15,
#  '[231': 3,
#  '231': 15,
#  '[232': 3,
#  '232': 15,
#  '[233': 3,
#  '233': 15,
#  '[234': 3,
#  '234': 15,
#  '[235': 3,
#  '235': 15,
#  '[236': 3,
#  '236': 15,
#  '[237': 3,
#  '237': 15,
#  '[238': 3,
#  '238': 15,
#  '[239': 3,
#  '239': 15,
#  '[240': 3,
#  '240': 15,
#  '[241': 3,
#  '241': 15,
#  '[242': 3,
#  '242': 15,
#  '[243': 3,
#  '243': 15,
#  '[244': 3,
#  '244': 15,
#  '[245': 3,
#  '245': 15,
#  '[246': 3,
#  '246': 15,
#  '[247': 3,
#  '247': 15,
#  '[248': 3,
#  '248': 15,
#  '[249': 3,
#  '249': 15,
#  '[250': 3,
#  '250': 15,
#  '[251': 3,
#  '251': 15,
#  '[252': 3,
#  '252': 15,
#  '[253': 3,
#  '253': 15,
#  '[254': 3,
#  '254': 15,
#  '[255': 3,
#  '255': 15,
#  '[256': 3,
#  '256': 15,
#  '[257': 3,
#  '257': 15,
#  '[258': 3,
#  '258': 15,
#  '[259': 3,
#  '259': 15,
#  '[260': 3,
#  '260': 15,
#  '[261': 3,
#  '261': 15,
#  '[262': 3,
#  '262': 15,
#  '[263': 3,
#  '263': 15,
#  '[264': 3,
#  '264': 15,
#  '[265': 3,
#  '265': 15,
#  '[266': 3,
#  '266': 15,
#  '[267': 3,
#  '267': 15,
#  '[268': 3,
#  '268': 15,
#  '[269': 3,
#  '269': 15,
#  '[270': 3,
#  '270': 15,
#  '[271': 3,
#  '271': 15,
#  '[272': 3,
#  '272': 15,
#  '[273': 3,
#  '273': 15,
#  '[274': 3,
#  '274': 15,
#  '[275': 3,
#  '275': 15,
#  '[276': 3,
#  '276': 15,
#  '[277': 3,
#  '277': 15,
#  '[278': 3,
#  '278': 15,
#  '[279': 3,
#  '279': 15,
#  '[280': 3,
#  '280': 15,
#  '[281': 3,
#  '281': 15,
#  '[282': 3,
#  '282': 15,
#  '[283': 3,
#  '283': 15,
#  '[284': 3,
#  '284': 15,
#  '[285': 3,
#  '285': 15,
#  '[286': 3,
#  '286': 15,
#  '[287': 3,
#  '287': 15,
#  '[288': 3,
#  '288': 15,
#  '[289': 3,
#  '289': 15,
#  '[290': 3,
#  '290': 15,
#  '[291': 3,
#  '291': 15,
#  '[292': 3,
#  '292': 12,
#  '[293': 3,
#  '293': 9,
#  '[294': 3,
#  '294': 6,
#  '[295': 3,
#  '295': 3,
#  '[296': 3,
#  'columns]empty': 2}
